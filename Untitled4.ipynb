# %%
#We import required libraries for this tutorial. We use a LinearRegression class of Scikit-Learn library in Python.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

#Next, we create random sample data.

x=list(range(50))
y=np.random.randint(1,20,50)+x

train_x=np.array(x)
train_y=np.array(y)

#Checking the elements of train_x and train_y arrays.

 


>> print("x:",train_x[1:10], "\ny:",train_y[1:10])
x: [1 2 3 4 5 6 7 8 9]
y: [19 15  7 22 14 25 16 15 10]

#We created test data. Next, we build a linear model and fit a test data.

model = LinearRegression(fit_intercept=True)
model.fit(train_x[:,np.newaxis], train_y[:,np.newaxis])

#Predicting a test data.

yfit=model.predict(train_x[:,np.newaxis])

Plotting the results.

plt.scatter(train_x, train_y)
plt.plot(train_x, yfit, color='red');
plt.show()





#Finally, we check model by calculating coefficients manually. We use y=a+bx formula to calculate elements of train_x array and compare them with yfit outputs.


>> print("Coef:",model.coef_, " Intercept:",model.intercept_)
Coef: [[0.95659064]]  Intercept: [9.34352941]
 

 
 
print(model.intercept_+model.coef_*[1,2,3,4])
[[10.30012005 11.25671068 12.21330132 13.16989196]]

print(yfit[1:5])
[[10.30012005]
 [11.25671068]
 [12.21330132]
 [13.16989196]]

#The results are the same.

#The full source code looks as below.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x=list(range(50))
y=np.random.randint(1,20,50)+x

train_x=np.array(x)
train_y=np.array(y)

model = LinearRegression(fit_intercept=True)
model.fit(train_x[:,np.newaxis], train_y[:,np.newaxis])
print("Coef:",model.coef_, " Intercept:",model.intercept_)

yfit=model.predict(train_x[:,np.newaxis])

plt.scatter(train_x, train_y)
plt.plot(train_x, yfit, color='red');
plt.show()
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp/ipykernel_22596/3765844007.py", line 20
#     >> print("x:",train_x[1:10], "\ny:",train_y[1:10])
#     ^
# SyntaxError: invalid syntax
